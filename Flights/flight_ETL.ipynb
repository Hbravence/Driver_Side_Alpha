# %%
#import's
from dotenv import load_dotenv
import os
import csv
import requests
import time
from datetime import datetime, timedelta 
#Loading API key's from .env file
load_dotenv()
api_key = os.getenv("API_KEY")
base_url = os.getenv("BASE_URL")
IATA_CODE = "MCI" #Kansas City
TYPE = "arrival"
#this code is so the API automatically pull's next's weeks flight schedule
start_date = datetime.today() + timedelta(days=8)
date_range = [start_date + timedelta(days=i) for i in range(7)]

# %%
all_flights_week = []
# this is date loop for the API so each day of the week get's called
for date in date_range:
    formatted_date = date.strftime("%Y-%m-%d")
    params = {
        "iataCode": IATA_CODE,
        "type": TYPE,
        "date": formatted_date,
        "access_key": api_key
    }

    response = requests.get(base_url, params=params)

    if response.status_code == 200:
        data = response.json().get("data", [])
        if data:
            for flight in data:
                flight["flight_date"] = formatted_date 

            all_flights_week.extend(data)
            print(f"✅ Retrieved {len(data)} flights")
        else:
            print(f"⚠️ No data returned for {formatted_date}")
    else:
        print(f"❌ Error {response.status_code}: {response.text}")
        
        break
# Time is a full minute between each loop because that has to with the rate limit, 
# the loop is also designed to break if it fails and then the data is supposed to be dropped
    
    time.sleep(60)
# Out:
# ✅ Retrieved 251 flights
# ✅ Retrieved 280 flights
# ✅ Retrieved 201 flights
# ✅ Retrieved 252 flights
# ✅ Retrieved 242 flights
# ✅ Retrieved 280 flights
# ✅ Retrieved 248 flights

# %%
import pandas as pd
from pandas import json_normalize

# %%
#it was a pretty clean JSON file so not diffcult to parse with a standard JSON_normalize

df = json_normalize(all_flights_week, sep='_')
columns_to_keep = [
    'flight_date',
    'weekday',
    'arrival_iataCode',
    'arrival_terminal',
    'arrival_scheduledTime',
    'departure_iataCode',
    'airline_name',
    'flight_iataNumber',
    'aircraft_modelText'
]

df_filtered = df[columns_to_keep]


df.head()
# Out:
#   weekday flight_date departure_iataCode departure_icaoCode  \
# 0       3  2025-07-30                phx               kphx
# 1       3  2025-07-30                phx               kphx
# 2       3  2025-07-30                atl               katl
# 3       3  2025-07-30                atl               katl
# 4       3  2025-07-30                atl               katl
#
#   departure_terminal departure_gate departure_scheduledTime arrival_iataCode  \
# 0                  4                                  18:55              mci
# 1                  4                                  18:55              mci
# 2                  s                                  08:20              mci
# 3                  s                                  08:20              mci
# 4                  s                                  08:20              mci
#
#   arrival_icaoCode arrival_terminal  ... airline_icaoCode flight_number  \
# 0             kmci                   ...              jag          4285
# 1             kmci                   ...              aal           623
# 2             kmci                   ...              lan          6120
# 3             kmci                   ...              wja          7243
# 4             kmci                   ...              dal          2471
#
#   flight_iataNumber flight_icaoNumber codeshared_airline_name  \
# 0            as4285           jag4285       american airlines
# 1             aa623            aal623                     NaN
# 2            la6120           lan6120         delta air lines
# 3            ws7243           wja7243         delta air lines
# 4            dl2471           dal2471                     NaN
#
#   codeshared_airline_iataCode codeshared_airline_icaoCode  \
# 0                          aa                         aal
# 1                         NaN                         NaN
# 2                          dl                         dal
# 3                          dl                         dal
# 4                         NaN                         NaN
#
#   codeshared_flight_number codeshared_flight_iataNumber  \
# 0                      623                        aa623
# 1                      NaN                          NaN
# 2                     2471                       dl2471
# 3                     2471                       dl2471
# 4                      NaN                          NaN
#
#   codeshared_flight_icaoNumber
# 0                       aal623
# 1                          NaN
# 2                      dal2471
# 3                      dal2471
# 4                          NaN
#
# [5 rows x 26 columns]

# %%
# then a time stamp is created to perserve a file with todays data, so it can be reference in historic sense
timestamp = datetime.now().strftime('%Y%m%d_%H%M')
raw_path = f"flight_data/raw/flight_arrivals_{timestamp}.csv"
df_filtered.to_csv(raw_path, index=False)
